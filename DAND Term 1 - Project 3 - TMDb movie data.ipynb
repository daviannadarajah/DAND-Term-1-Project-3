# %% [markdown]
# # Project: TMDb movie data investigation on movie net profit and ROI
#
# ## Table of Contents
# <ul>
# <li><a href="#intro">Introduction</a></li>
# <li><a href="#wrangling">Data Wrangling</a></li>
# <li><a href="#eda">Exploratory Data Analysis</a></li>
# <li><a href="#conclusions">Conclusions</a></li>
# </ul>

# %% [markdown]
# <a id='intro'></a>
# ## Introduction
#
# This data set contains data on just over 10,000 movies collected from The Movie Database (TMDb). It was downloaded [here](https://d17h27t6h515a5.cloudfront.net/topher/2017/October/59dd1c4c_tmdb-movies/tmdb-movies.csv). Below is a data dictionary and assumptions made as I was not able to find enough information for each column.
#
# - **id:** unique identifier in this dataset.
# - **imdb_id:** unique identifer on imdb website.
# - **popularity:** see definition [here](https://developers.themoviedb.org/3/getting-started/popularity).
# - **budget:** this is expressed in nominal U.S dollars.
# - **revenue:** this is expressed in nominal U.S dollars. Assumed to be worldwide gross revenue.
# - **original_title:** title of the movie when it was initally released.
# - **cast:** list of actors and actresses separated by '|'.
# - **homepage:** homepage of movie.
# - **director:** director of movie.
# - **tagline:** tagline promoting the movie.
# - **keywords:** words used to describe the film.
# - **overview:** short description of what the movie is about.
# - **run-time**: duration of the movie.
# - **genres:** category types associated with the movie (Eg. thriller, fantasy, action, etc). Separated by '|'.
# - **production_companies:** companies involved in the production of the movie, separated by '|'.
# - **release_date:** expressed in 'yyy-mm-dd' (after data wrangling).
# - **vote_count:** how many votes contributed to the movie rating out of 10.
# - **vote_average:** average rating out of 10, with 1 being least favourable and 10 being most favourable.
# - **release_year:** expressed in 'yyyy'. Assumed to be the year the movie was initally released and does not include when it was last re-released.
# - **budget_adj:** assumed to be expressed in terms of 2010 U.S dollars (ie. adjustment for inflation over time).
# - **revenue_adj:** assumed to be expressed in in terms of 2010 U.S dollars (ie. adjustment for inflation over time). Assumed to be worldwide gross revenue.
#
# ### Investigation
#
# Movies these days are always looking to outdo their predecessors in terms of commercial success. Movie production companies are also looking to maximise the use of their resources (physical and monetary) to generate the most profit.
#
# For this analysis I've decided to use the adjusted net profit (`revenue_adj` - `budget_adj`) as a a measure of box office success. Adjusting for inflation allows for a fairer financial comparision between movies of present and those in the past. In my view, if a movie generates a lot of revenue, it does not mean it has been a commercial success if it is very costly to make.
#
# By the same token, just because movies have generated a lot of net profit doesn't mean the Return On Investment (ROI) was spectacular. For example, if you've generated \$120 million in net profit but it cost \$100 million to make, then your ROI is for every \$1 invested, it generated $1.20 back. As an investor or production company, you should not ignore movies that have excellent ROI that are cheaper to make. They are still good investments!
#
# So it is important to strike a balance between generated large net profit but also prioritising movies that have a strong ROI. As such, the questions that I would like to explore are:
#
# 1. How do the 10 highest profitable movies perform in terms of ROI?
# 2. How do the 10 highest ROI movies perform in terms of profitability?
# 3. When during the year are profitable movies released?
# 4. What is the correlation between the popularity score and net profit?
# 5. What is the correlation between the financial metrics and vote_average?
#
# Note that I've chosen to focus my analysis on the top 50% commercially successful moves in terms of net profit and ROI.

# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import pyplot
import seaborn as sns
from datetime import datetime

# Enable visualisations within Jupyter notebook
% matplotlib inline

# This helps display data to two decimal places and inserts a comma separator for large figures in '000s.
pd.options.display.float_format = "{:,.2f}".format

# %% [markdown]
# <a id='wrangling'></a>
# ## Data Wrangling
#
# ### General Properties

# %%
# Load your data and print out a few lines. Perform operations to inspect data
#   types and look for instances of missing or possibly errant data.

df = pd.read_csv('C:/Users/MyTecra/Downloads/Udacity - Data Analytics/Project 3 - Investigate a Dataset/tmdb-movies.csv')
df.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610       32.99  150000000  1513528810
# 1   76341  tt1392190       28.42  150000000   378436354
# 2  262500  tt2908446       13.11  110000000   295238201
# 3  140607  tt2488496       11.17  200000000  2068178225
# 4  168259  tt2820852        9.34  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %% [markdown]
# #### Initial observations
# - Looking at the above first five rows, there are 21 columns and the data under each column reveals that types of possible data formats each are expressed in.
# - `vote_average` seems to represent the movie's average rating out of 10 (with 10 being high and 0 being low). This will be a critical field to determine the viewer's assessment of the film for the last question I'm investigating.
# - There are `budget`, `revenue`, `budget_adj` and `revenue_adj` columns. These will be critical but I will likely only need the latter two since I want to make meaningful comparison on the financial performance of each film. Numbers would need to be adjusted for inflation to make this happen. The monetary denomination isn't specified so I will assume this is expressed in $USD.
# - It looks like the `cast`, `genre` and `production_companies` columns have a list of names or descriptions separated by a '|'. Except `genre`, I won't need these fields since it is out of scope.
# - I also am not able to see all the column information because there are too many to display.
#
# Let's keep looking...

# %%
print(df.shape)
print('')
df.info()
# Out:
# (10866, 21)
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
# id                      10866 non-null int64
# imdb_id                 10856 non-null object
# popularity              10866 non-null float64
# budget                  10866 non-null int64
# revenue                 10866 non-null int64
# original_title          10866 non-null object
# cast                    10790 non-null object
# homepage                2936 non-null object
# director                10822 non-null object
# tagline                 8042 non-null object
# keywords                9373 non-null object
# overview                10862 non-null object
# runtime                 10866 non-null int64
# genres                  10843 non-null object
# production_companies    9836 non-null object
# release_date            10866 non-null object
# vote_count              10866 non-null int64
# vote_average            10866 non-null float64
# ...

# %% [markdown]
# The above indicates there are:
# - 10866 rows and 21 columns
# - The data types for each column seem quite sensible in terms of numeric expressions I'd expect to see (eg. `runtime`, `vote average`, `vote_count`, `budget`, `revenue`, etc) being in either float or int.
# - The `release_date` (a string) and `release_year` should be converted to time.
# - However, there seem to be a some missing data for `imdb_id`, `cast`, `homepage`, `director`, `tagline`, `keywords`, `overview`, `genres` and `production_companies.` Apart from `genres` this is of little consequences as I won't be using a lot of these columns.
# - The `keywords` column is the only one I cannot see using head()
# - There could also be duplicates so we'll investigate this, the null information further, and what sort of text are in keywords.
#
# Let's take a closer look at each of the data in each column.

# %% [markdown]
# ### Data Cleaning

# %%
# Check duplicates
print(df.duplicated().sum())
df[df.duplicated()]
# Out:
# 1
#          id    imdb_id  popularity    budget  revenue original_title  \
# 2090  42194  tt0411951        0.60  30000000   967000         TEKKEN
#
#                                                    cast homepage  \
# 2090  Jon Foo|Kelly Overton|Cary-Hiroyuki Tagawa|Ian...      NaN
#
#               director              tagline     ...       \
# 2090  Dwight H. Little  Survival is no game     ...
#
#                                                overview runtime  \
# 2090  In the year of 2039, after World Wars destroy ...      92
#
#                                            genres    production_companies  \
# 2090  Crime|Drama|Action|Thriller|Science Fiction  Namco|Light Song Films
#
#      release_date vote_count  vote_average  release_year    budget_adj  \
# 2090      3/20/10        110          5.00          2010 30,000,000.00
#
#       revenue_adj
# 2090   967,000.00
#
# [1 rows x 21 columns]

# %%
# Only 1 duplicate -let's see what it is
df.query('original_title == "TEKKEN"')
# Out:
#          id    imdb_id  popularity    budget  revenue original_title  \
# 2089  42194  tt0411951        0.60  30000000   967000         TEKKEN
# 2090  42194  tt0411951        0.60  30000000   967000         TEKKEN
#
#                                                    cast homepage  \
# 2089  Jon Foo|Kelly Overton|Cary-Hiroyuki Tagawa|Ian...      NaN
# 2090  Jon Foo|Kelly Overton|Cary-Hiroyuki Tagawa|Ian...      NaN
#
#               director              tagline     ...       \
# 2089  Dwight H. Little  Survival is no game     ...
# 2090  Dwight H. Little  Survival is no game     ...
#
#                                                overview runtime  \
# 2089  In the year of 2039, after World Wars destroy ...      92
# 2090  In the year of 2039, after World Wars destroy ...      92
#
#                                            genres    production_companies  \
# 2089  Crime|Drama|Action|Thriller|Science Fiction  Namco|Light Song Films
# ...

# %%
#The above indicates there is only one duplicate row. So we will drop this.
df.drop_duplicates(keep ='first', inplace=True)
df.duplicated().sum()
# Out:
# 0

# %%
# convert time
df['release_date'] = pd.to_datetime(df['release_date'])

# create a new field release_month to help answer Question 3 on when highly profitable movies are released.
df['release_month'] = df['release_date'].dt.month
print(df[['release_date','release_year','release_month']].dtypes)
df.tail(2)
# Out:
# release_date     datetime64[ns]
# release_year              int64
# release_month             int64
# dtype: object
#           id    imdb_id  popularity  budget  revenue  \
# 10864  21449  tt0061177        0.06       0        0
# 10865  22293  tt0060666        0.04   19000        0
#
#                  original_title  \
# 10864    What's Up, Tiger Lily?
# 10865  Manos: The Hands of Fate
#
#                                                     cast homepage  \
# 10864  Tatsuya Mihashi|Akiko Wakabayashi|Mie Hama|Joh...      NaN
# 10865  Harold P. Warren|Tom Neyman|John Reynolds|Dian...      NaN
#
#                director                                       tagline  \
# 10864       Woody Allen                     WOODY ALLEN STRIKES BACK!
# 10865  Harold P. Warren  It's Shocking! It's Beyond Your Imagination!
#
#            ...       runtime         genres     production_companies  \
# 10864      ...            80  Action|Comedy  Benedict Pictures Corp.
# ...

# %% [markdown]
# The above highlights an anomaly with the `release_date`; the year in it does not match the `release_year`! How can you have a 2066 year for the `release date`? Which is correct? Wikipedia confirms the `release_year` of 1966 is correct for _What's Up Tiger Lily_ and _Manos: The Hands of Fate_. So we'll need to compare the year in `release_date` to `release_year`. I've decided to make the assumption that the year in `release_date` is correct unless it is something completely ridiculous like 2066. If this is the case, then I would need to take the `release_year` as correct and use that as the year for the `release_date`. The below confirms that `release_year` has sensible dates since the maximum year is 2015.

# %%
df['release_year'].describe()
# Out:
# count   10,865.00
# mean     2,001.32
# std         12.81
# min      1,960.00
# 25%      1,995.00
# 50%      2,006.00
# 75%      2,011.00
# max      2,015.00
# Name: release_year, dtype: float64

# %%
# Extract the year from release date
df['year_temp'] = df['release_date'].dt.year

# Convert to same data type as release_year for comparison
df['year_temp'] = df['year_temp'].apply(int) 

# Check which years don't look correct.
df['year_temp'].value_counts().sort_index()
# Out:
# 1968     39
# 1969     31
# 1970     41
# 1971     55
# 1972     40
# 1973     55
# 1974     47
# 1975     44
# 1976     47
# 1977     57
# 1978     65
# 1979     57
# 1980     78
# 1981     82
# 1982     81
# 1983     80
# 1984    105
# 1985    109
# 1986    121
# 1987    125
# 1988    145
# 1989    137
# 1990    132
# 1991    133
# 1992    133
# 1993    178
# 1994    184
# 1995    175
# 1996    204
# 1997    192
# 1998    210
# 1999    224
# 2000    227
# 2001    242
# 2002    266
# 2003    281
# 2004    307
# 2005    364
# 2006    408
# 2007    438
# 2008    496
# 2009    533
# 2010    489
# 2011    540
# 2012    588
# 2013    659
# 2014    700
# 2015    629
# 2060     32
# 2061     31
# 2062     32
# 2063     34
# 2064     42
# 2065     35
# 2066     46
# 2067     40
# Name: year_temp, dtype: int64

# %%
# Now we need to clean up years 2060-2067. We'll use the  release_year for this.
df.loc[df['year_temp'] >= 2060, 'year_temp'] = df['release_year']

#check if fixed 
df['year_temp'].value_counts().sort_index()
# Out:
# 1960     32
# 1961     31
# 1962     32
# 1963     34
# 1964     42
# 1965     35
# 1966     46
# 1967     40
# 1968     39
# 1969     31
# 1970     41
# 1971     55
# 1972     40
# 1973     55
# 1974     47
# 1975     44
# 1976     47
# 1977     57
# 1978     65
# 1979     57
# 1980     78
# 1981     82
# 1982     81
# 1983     80
# 1984    105
# 1985    109
# 1986    121
# 1987    125
# 1988    145
# 1989    137
# 1990    132
# 1991    133
# 1992    133
# 1993    178
# 1994    184
# 1995    175
# 1996    204
# 1997    192
# 1998    210
# 1999    224
# 2000    227
# 2001    242
# 2002    266
# 2003    281
# 2004    307
# 2005    364
# 2006    408
# 2007    438
# 2008    496
# 2009    533
# 2010    489
# 2011    540
# 2012    588
# 2013    659
# 2014    700
# 2015    629
# Name: year_temp, dtype: int64

# %%
# convert to strings for concatenation
df['release_date'] = df['release_date'].astype(str)
df['year_temp'] = df['year_temp'].astype(str)

# %%
# remove the year from release date
df['release_date'] = df['release_date'].apply(lambda x: x[4:])

# %%
# add the year with the correct one
df['release_date'] = df['year_temp'] + df['release_date']

# %%
#check
df['release_date'].value_counts().sort_index()
# Out:
# 1960-01-01    2
# 1960-02-11    1
# 1960-02-22    1
# 1960-03-01    1
# 1960-03-27    1
# 1960-04-06    1
# 1960-05-18    1
# 1960-05-19    1
# 1960-06-15    1
# 1960-06-19    1
# 1960-06-21    1
# 1960-06-24    1
# 1960-07-01    1
# 1960-07-13    1
# 1960-07-20    1
# 1960-08-05    1
# 1960-08-10    1
# 1960-08-14    1
# 1960-08-17    1
# 1960-08-29    1
# 1960-09-09    1
# 1960-09-14    1
# 1960-10-06    1
# 1960-10-07    1
# 1960-10-13    1
# 1960-10-23    1
# 1960-10-24    1
# 1960-12-18    1
# 1960-12-20    1
# 1960-12-21    1
#              ..
# 2015-11-09    1
# 2015-11-10    2
# 2015-11-12    3
# 2015-11-13    6
# 2015-11-14    1
# 2015-11-15    1
# 2015-11-18    1
# 2015-11-20    4
# 2015-11-22    1
# 2015-11-25    2
# 2015-11-26    3
# 2015-11-27    4
# 2015-12-01    2
# 2015-12-03    1
# 2015-12-04    4
# 2015-12-05    1
# 2015-12-11    6
# 2015-12-14    1
# 2015-12-15    1
# 2015-12-17    1
# 2015-12-18    2
# 2015-12-19    2
# 2015-12-20    1
# 2015-12-23    2
# ...

# %%
#convert back to datetime
df['release_date'] = pd.to_datetime(df['release_date'])

#change release_year to match the year in release_date
df['release_year'] = df['release_date'].dt.year
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10865 entries, 0 to 10865
# Data columns (total 23 columns):
# id                      10865 non-null int64
# imdb_id                 10855 non-null object
# popularity              10865 non-null float64
# budget                  10865 non-null int64
# revenue                 10865 non-null int64
# original_title          10865 non-null object
# cast                    10789 non-null object
# homepage                2936 non-null object
# director                10821 non-null object
# tagline                 8041 non-null object
# keywords                9372 non-null object
# overview                10861 non-null object
# runtime                 10865 non-null int64
# genres                  10842 non-null object
# production_companies    9835 non-null object
# release_date            10865 non-null datetime64[ns]
# vote_count              10865 non-null int64
# vote_average            10865 non-null float64
# ...

# %%
#check if min / max release_year is ok
df['release_year'].describe()
# Out:
# count   10,865.00
# mean     2,001.32
# std         12.81
# min      1,960.00
# 25%      1,995.00
# 50%      2,006.00
# 75%      2,011.00
# max      2,015.00
# Name: release_year, dtype: float64

# %%
# How many null values are there in each column?
df.isnull().sum()
# Out:
# id                         0
# imdb_id                   10
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# cast                      76
# homepage                7929
# director                  44
# tagline                 2824
# keywords                1493
# overview                   4
# runtime                    0
# genres                    23
# production_companies    1030
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# budget_adj                 0
# revenue_adj                0
# release_month              0
# year_temp                  0
# dtype: int64

# %%
#There are rows with zero dollar values for budget and revenue. Let's remove this as they are useless.
columns =['budget', 'revenue']

# Replace zero values with NAN and print NA results
df[columns] = df[columns].replace(0, np.NAN)
print(df[columns].isnull().sum())

# Drop rows with NAN for budget_adj and revenue_adj
df.dropna(subset = columns, inplace = True)

print('')
print('Results after removing NA values:')
print(df[columns].isnull().sum())
# Out:
# budget     5696
# revenue    6016
# dtype: int64
#
# Results after removing NA values:
# budget     0
# revenue    0
# dtype: int64

# %%
# No null values against budget, revenue, budget_adj and revenue_adj which is good
# Let's look at the dataset
df.describe()
# Out:
#               id  popularity         budget          revenue  runtime  \
# count   3,854.00    3,854.00       3,854.00         3,854.00 3,854.00
# mean   39,888.19        1.19  37,203,696.95   107,686,616.10   109.22
# std    67,222.53        1.48  42,208,224.69   176,539,346.11    19.92
# min         5.00        0.00           1.00             2.00    15.00
# 25%     6,073.50        0.46  10,000,000.00    13,600,032.25    95.00
# 50%    11,321.50        0.80  24,000,000.00    44,800,002.50   106.00
# 75%    38,573.25        1.37  50,000,000.00   124,212,540.75   119.00
# max   417,859.00       32.99 425,000,000.00 2,781,505,847.00   338.00
#
#        vote_count  vote_average  release_year     budget_adj      revenue_adj  \
# count    3,854.00      3,854.00      3,854.00       3,854.00         3,854.00
# mean       527.72          6.17      2,001.26  44,239,993.08   137,064,690.30
# std        879.96          0.79         11.28  44,809,254.03   216,111,351.44
# ...

# %% [markdown]
# The above summary shows that the minimum figures for `budget_adj` (0.97) and `revenue_adj` (2.37) are absurd. This indicates that these movies do not have accurate financial information and needs further exploration.

# %%
#Let's check to see what budgets don't look right from the 30 smallest entries. 
df['budget_adj'].nsmallest(n=30)
# Out:
# 3581         0.97
# 2618         1.31
# 2398         3.00
# 8944         4.52
# 10050        5.01
# 8235         8.59
# 5852         9.36
# 8125        11.45
# 5162        11.85
# 10297       12.08
# 5785        14.04
# 3853        19.39
# 4675        23.74
# 10236       31.70
# 2519        32.73
# 10777       36.77
# 9992        50.07
# 1733        76.23
# 3968        82.43
# 3608        90.15
# 10495      224.80
# 6179       231.10
# 7813     6,310.01
# 3755     7,755.18
# 7044     8,081.12
# 7447    15,775.03
# 3785    16,479.77
# 2207    30,000.00
# 2227    30,000.00
# 1871    31,703.56
# Name: budget_adj, dtype: float64

# %%
# Some of the numbers below $30k look odd for movie budgets. Need to look at this closer.
df[(df['budget_adj'] <= 30000)]
# Out:
#            id    imdb_id  popularity    budget        revenue  \
# 1733    22717  tt1084972        0.28     75.00         134.00
# 2207    42296  tt1584016        0.35 30,000.00   3,045,943.00
# 2227    38568  tt1049402        0.28 30,000.00     617,000.00
# 2398    39356  tt1560139        0.03      3.00          43.00
# 2519    10397  tt0145653        0.35     25.00          13.00
# 2618    39964  tt0120836        0.09      1.00         100.00
# 3581    59296  tt1436559        0.52      1.00       1,378.00
# 3608    50217  tt0893412        0.46     93.00   2,500,000.00
# 3755    79120  tt1714210        0.24  8,000.00     469,947.00
# 3785    58699  tt1242599        0.20 17,000.00     101,236.00
# 3853    62796  tt1831829        0.10     20.00          15.00
# 3968     4614  tt0164184        0.96     68.00         193.00
# 4675    63574  tt1710396        0.32     25.00          30.00
# 5162    24914  tt0368574        0.21     10.00           5.00
# ...

# %% [markdown]
# The above has interesting results. Karate Kid Part 2 doesn't look right on row 10495. It cost \$113.00 to make (`budget`) and made \$115,103,979.00 (`revenue`) in the box office adjusted for inflation? According to Wikipedia, the budget should have been \$13m. To determine the budget adjusted for inflation, I entered $13m into the inflation calculator http://www.usinflationcalculator.com/. According to that, \$13m would cost \$25,864,306.57 in the year 2010.
#
# Paranormal activity checks out according to Wikipedia with its small \$15k budget and phenomenal gross revenue \$193.4m. The other entries do not look material in nature, and as I don't have time to fix them all, I'm going to drop everything below \$15k in budget so it doesn't distort the ROI and net profit figures which I'll calculate later.

# %%
#check the Karate Kid Part 2 is the right index
df.loc[10495]['budget_adj']
# Out:
# 224.802924427423

# %%
# insert correct figure.
df.replace(to_replace=224.802924427423, value=25864306.57, inplace=True)

#check index again
df.loc[10495]['budget_adj']
# Out:
# 25864306.57

# %%
# Filter out all budgets less than $15k from the dataset.
df = df[(df['budget_adj'] >= 15000)]

df.describe()
# Out:
#               id  popularity         budget          revenue  runtime  \
# count   3,830.00    3,830.00       3,830.00         3,830.00 3,830.00
# mean   39,864.02        1.20  37,436,821.54   108,358,776.85   109.27
# std    67,287.49        1.48  42,237,084.35   176,886,703.38    19.86
# min         5.00        0.00         113.00             2.00    26.00
# 25%     6,045.50        0.47  10,000,000.00    14,002,672.50    96.00
# 50%    11,286.50        0.80  24,000,000.00    45,658,770.50   106.00
# 75%    38,517.75        1.38  50,000,000.00   124,911,131.50   119.00
# max   417,859.00       32.99 425,000,000.00 2,781,505,847.00   338.00
#
#        vote_count  vote_average  release_year     budget_adj      revenue_adj  \
# count    3,830.00      3,830.00      3,830.00       3,830.00         3,830.00
# mean       530.52          6.17      2,001.26  44,523,962.01   137,919,153.01
# std        881.93          0.79         11.29  44,807,185.80   216,516,824.45
# ...

# %% [markdown]
# The above summary shows that `budget_adj` looks more sensible. However, `revenue_adj` has a minimum of \$2.37 and needs a closer look.

# %%
#Let's check to see what revenue doesn't look right from the 30 smallest entries.
df['revenue_adj'].nsmallest(n=30)
# Out:
# 5067         2.37
# 8142         2.86
# 3239         3.04
# 8523         6.95
# 8226         8.59
# 10307        9.06
# 7158        13.85
# 10294       22.64
# 5060        27.26
# 7506        48.38
# 9332       124.89
# 6707       155.76
# 4970       296.34
# 4668     1,840.60
# 4611     2,394.31
# 4495     2,852.08
# 4591     2,858.73
# 3621     3,255.24
# 7602     3,744.99
# 3752     5,046.69
# 5704     5,753.80
# 5586     5,989.68
# 1780     7,425.82
# 4540     7,729.97
# 6948     7,790.18
# 851      8,582.73
# 5697     8,631.16
# 5576     9,123.52
# 1871    10,164.00
# 6274    11,488.32
# Name: revenue_adj, dtype: float64

# %%
# Now having a look at the dataframe.
df[(df['revenue_adj'] <= 30000)]
# Out:
#            id    imdb_id  popularity         budget   revenue  \
# 331    245846  tt2325977        0.37  10,000,000.00 17,472.00
# 818    242042  tt2355495        0.73   6,000,000.00 15,071.00
# 851    254191  tt3177316        0.62   1,000,000.00  9,318.00
# 940    244783  tt2182972        0.41   6,000,000.00 32,251.00
# 1561    31723  tt1247704        0.53   3,000,000.00 18,097.00
# 1780    38850  tt1139282        0.22   2,000,000.00  7,306.00
# 1871    42151  tt1489167        0.09      31,192.00 10,000.00
# 3239    14301  tt1227926        0.35     200,000.00      3.00
# 3573    50601  tt1486193        0.54  20,000,000.00 17,479.00
# 3621    79070  tt1683921        0.43   2,500,000.00  3,358.00
# 3659    91070  tt1726589        0.37     930,000.00 30,905.00
# 3752    65650  tt1582271        0.24   6,000,000.00  5,206.00
# 3788    38541  tt1535616        0.19   3,000,000.00 22,000.00
# 4127    21925  tt0145937        0.19   3,000,000.00 13,308.00
# ...

# %% [markdown]
# It looks like a lot of the revenue figures are mistated despite complete budget information.
# We'll just have to ignore these unfortunately - they will return a net loss and be filtered out from the analysis as we are focussing on movies that have made a net profit.

# %%
# checking dataset size
df.shape
# Out:
# (3830, 23)

# %%
# Add net profit and ROI columns
df['net_profit'] = df['revenue_adj']-df['budget_adj']
df['ROI'] = df['net_profit'] / df['budget_adj']
df.head()
# Out:
#        id    imdb_id  popularity         budget          revenue  \
# 0  135397  tt0369610       32.99 150,000,000.00 1,513,528,810.00
# 1   76341  tt1392190       28.42 150,000,000.00   378,436,354.00
# 2  262500  tt2908446       13.11 110,000,000.00   295,238,201.00
# 3  140607  tt2488496       11.17 200,000,000.00 2,068,178,225.00
# 4  168259  tt2820852        9.34 190,000,000.00 1,506,249,360.00
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
# ...

# %% [markdown]
# Now I'm going to drop all the columns I am not going to use. These are:
# - `budget`
# - `revenue`
# - `cast`
# - `homepage`
# - `runtime`
# - `director`
# - `tagline`
# - `keywords`
# - `overview`
# - `production_companies`

# %%
# Dropping unused columns
df= df.drop(['budget', 'revenue', 'cast', 'homepage', 'director', 'runtime',
         'tagline', 'keywords', 'overview', 'production_companies'], axis=1)

# %%
# Finally, let's filter out the movies that made a profit.
df = df.query('net_profit > 0')
print(df.shape)
df.describe()
# Out:
# (2759, 15)
#               id  popularity  vote_count  vote_average  release_year  \
# count   2,759.00    2,759.00    2,759.00      2,759.00      2,759.00
# mean   38,426.16        1.42      682.69          6.30      2,000.57
# std    67,495.21        1.67      991.56          0.76         12.00
# min         5.00        0.00       10.00          3.40      1,960.00
# 25%     2,915.50        0.57      122.00          5.80      1,994.00
# 50%    10,623.00        0.99      320.00          6.30      2,004.00
# 75%    36,887.00        1.66      785.00          6.80      2,010.00
# max   417,859.00       32.99    9,767.00          8.40      2,015.00
#
#           budget_adj      revenue_adj  release_month       net_profit  \
# count       2,759.00         2,759.00       2,759.00         2,759.00
# mean   47,950,287.67   184,267,429.77           7.07   136,317,142.10
# std    47,626,145.70   239,144,346.22           3.35   213,889,566.47
# ...

# %% [markdown]
# The above indicates there seems to be really big outliers as the the median and mean are vastly different for `net_profit` and `ROI`. To get a better understanding for the  commercially successful movies, I will narrow the dataset further by considering only those in the top 50% in the dataset for `net_profit` or `ROI`. As mentioned in the introduction,  movies are try to outdo past movies in commercial performance so looking at what the top 50% in this dataset to see what makes them special seems sensible.

# %%
df = df.query('net_profit >= net_profit.median() | ROI >= ROI.median()')
print(df.shape)
df.describe()
# Out:
# (1757, 15)
#               id  popularity  vote_count  vote_average  release_year  \
# count   1,757.00    1,757.00    1,757.00      1,757.00      1,757.00
# mean   36,903.33        1.71      887.93          6.41      1,999.78
# std    66,887.10        1.94    1,139.69          0.74         12.67
# min        11.00        0.00       10.00          3.40      1,960.00
# 25%     1,817.00        0.69      184.00          5.90      1,993.00
# 50%     9,837.00        1.21      480.00          6.40      2,003.00
# 75%    36,658.00        2.04    1,097.00          6.90      2,010.00
# max   417,859.00       32.99    9,767.00          8.40      2,015.00
#
#           budget_adj      revenue_adj  release_month       net_profit  \
# count       1,757.00         1,757.00       1,757.00         1,757.00
# mean   55,152,256.17   257,202,312.41           7.18   202,050,056.24
# std    53,448,871.15   272,483,564.09           3.35   244,508,397.47
# ...

# %% [markdown]
# The next two cells deal with assigning a rank in order of greatest to lease for net profit and ROI for each movie.

# %%
# Rank movies with the greatest net profit from most to lease
df.sort_values('net_profit', inplace=True, ascending=False)
df['np_rank'] = range(len(df))

# Add 1 so that the higher net profit movie starts with rank 1 and not zero due to zero-based indexing with range.
df['np_rank'] = df['np_rank'] + 1

# check if output looks ok
df.head(3)
# Out:
#          id    imdb_id  popularity original_title  \
# 1329     11  tt0076759       12.04      Star Wars
# 1386  19995  tt0499549        9.43         Avatar
# 5231    597  tt0120338        4.36        Titanic
#
#                                         genres release_date  vote_count  \
# 1329          Adventure|Action|Science Fiction   1977-03-20        4428
# 1386  Action|Adventure|Fantasy|Science Fiction   2009-12-10        8458
# 5231                    Drama|Romance|Thriller   1997-11-18        4654
#
#       vote_average  release_year     budget_adj      revenue_adj  \
# 1329          7.90          1977  39,575,591.36 2,789,712,242.28
# 1386          7.10          2009 240,886,902.89 2,827,123,750.41
# 5231          7.30          1997 271,692,064.21 2,506,405,735.42
#
#       release_month year_temp       net_profit   ROI  np_rank
# 1329              3      1977 2,750,136,650.92 69.49        1
# 1386             12      2009 2,586,236,847.52 10.74        2
# ...

# %%
# Assign rank to highest ROI movies, greatest to lease.
df.sort_values('ROI', inplace=True, ascending=False)
df['ROI_rank'] = range(len(df))

# Add 1 so that the higher ROI movie starts with rank 1 and not zero due to zero-based indexing with range.
df['ROI_rank'] = df['ROI_rank'] + 1

# check if output looks ok
df.head(3)
# Out:
#          id    imdb_id  popularity           original_title  \
# 7447  23827  tt1179904        1.12      Paranormal Activity
# 2449   2667  tt0185937        0.93  The Blair Witch Project
# 1354    985  tt0074486        0.33               Eraserhead
#
#                                     genres release_date  vote_count  \
# 7447                        Horror|Mystery   2007-09-14         714
# 2449                        Horror|Mystery   1999-07-14         522
# 1354  Science Fiction|Fantasy|Horror|Drama   1977-03-19         194
#
#       vote_average  release_year  budget_adj    revenue_adj  release_month  \
# 7447          6.10          2007   15,775.03 203,346,220.13              9
# 2449          6.30          1999   32,726.32 324,645,105.96              7
# 1354          7.10          1977   35,977.81  25,184,467.23              3
#
#      year_temp     net_profit       ROI  np_rank  ROI_rank
# 7447      2007 203,330,445.10 12,889.39      532         1
# ...

# %% [markdown]
# <a id='eda'></a>
# ### Exploratory Data Analysis
#
# The below quickly explores data as a single variable to give an understanding of what to expect before moving on to two dimensional variables (eg. ROI vs net profit).

# %%
# Looking at net profit distribution
plt.xlabel('net_profit ($B)')
plt.ylabel('frequency')
plt.title('Movie distribution by net profit')
df['net_profit'].hist()

# %% [markdown]
# It would appear that the majority of the movies in the filtered dataset have earned between \$0 and \$250m. This may suggest that it is unusal for a movie to gross more than $250m, or perhaps it is less risky to aim for profitable movie within this range.

# %%
# Exploring vote average
plt.xlabel('vote_average')
plt.ylabel('frequency')
plt.title('Movie distribution by vote_average')
df['vote_average'].hist()

# %% [markdown]
# The above plot indicates it is common for movies in the top 50% for net profit or ROI to attract scores of between 6 to 7 out of 10. This may be a predictor of a movie success when doing a pre-screening and seeking average voting scores from audiences. The results are also suprising as the implication would be that you don't need to achieve a high average score (eg. at least 8 out of 10) to be a commercially successful movie.

# %%
# What is the most popular month for releasing movies?
plt.xlabel('Calendar month by number')
plt.ylabel('frequency')
plt.title('Movie distribution by release month (Jan = 1, Feb = 2, Mar = 3... Dec = 12)')
df['release_month'].hist()

# %% [markdown]
# The above historgram indicates that December is an immensely popular month for releasing movies. The second most popular appears to be June.

# %% [markdown]
# #### ROI and Net Profit exploration
#
# The below cells quickly look at the ROI and net profit figures to see if they seem sensible and to get quick insights into the filtered dataset. Then the individual research questions follow after it.

# %%
df.describe()
# Out:
#               id  popularity  vote_count  vote_average  release_year  \
# count   1,757.00    1,757.00    1,757.00      1,757.00      1,757.00
# mean   36,903.33        1.71      887.93          6.41      1,999.78
# std    66,887.10        1.94    1,139.69          0.74         12.67
# min        11.00        0.00       10.00          3.40      1,960.00
# 25%     1,817.00        0.69      184.00          5.90      1,993.00
# 50%     9,837.00        1.21      480.00          6.40      2,003.00
# 75%    36,658.00        2.04    1,097.00          6.90      2,010.00
# max   417,859.00       32.99    9,767.00          8.40      2,015.00
#
#           budget_adj      revenue_adj  release_month       net_profit  \
# count       1,757.00         1,757.00       1,757.00         1,757.00
# mean   55,152,256.17   257,202,312.41           7.18   202,050,056.24
# std    53,448,871.15   272,483,564.09           3.35   244,508,397.47
# ...

# %% [markdown]
# There are 1,757 rows of data. The 75% percentile is at 6.81 ROI and $242.9m net profit.

# %%
# General look at data - net_profit vs ROI
df.plot(x="net_profit", y="ROI", kind="scatter")
plt.xlabel('net_profit ($B)')
plt.title('ROI vs net_profit comparison')
plt.show()

# %% [markdown]
# The above scatter graph really highlights the outliers. The two with the highest ROI are Paranormal Activity and The Blair Witch Project. The ones on the extreme right are Star Wars, Avatar and Titanic (starting from rightmost). Let's look at it with some better scaling involving the first 75% of results (to knockout the outliers) as published in the above df.describe() statistics.

# %%
# scatterplot
df.plot(x="net_profit", y="ROI", kind="scatter")
plt.xlabel('net_profit ($B)')
plt.title('Movies up to 75% percentile')
plt.xlim(0, df["net_profit"].quantile(0.75))
plt.ylim(0, df["ROI"].quantile(0.75))
plt.show()

# %%
df["net_profit"].quantile(0.75)
# Out:
# 242916410.82805386

# %% [markdown]
# The above scatterplot is quite telling with nothing in the region bound by the coordinates of approximately 2 ROI and \$0.6B net profit.

# %% [markdown]
# ### Research Question 1 - How do the 10 highest profitable movies perform in terms of ROI?

# %%
df.nlargest(10, columns='net_profit')
# Out:
#            id    imdb_id  popularity                  original_title  \
# 1329       11  tt0076759       12.04                       Star Wars
# 1386    19995  tt0499549        9.43                          Avatar
# 5231      597  tt0120338        4.36                         Titanic
# 10594    9552  tt0070047        2.01                    The Exorcist
# 9806      578  tt0073195        2.56                            Jaws
# 8889      601  tt0083866        2.90      E.T. the Extra-Terrestrial
# 3      140607  tt2488496       11.17    Star Wars: The Force Awakens
# 8094     1642  tt0113957        1.14                         The Net
# 10110   12230  tt0055254        2.63  One Hundred and One Dalmatians
# 7309     1891  tt0080684        5.49         The Empire Strikes Back
#
#                                          genres release_date  vote_count  \
# 1329           Adventure|Action|Science Fiction   1977-03-20        4428
# ...

# %% [markdown]
# The above indicates that these highly profitable movies returned strong ROIs - all are in the top 25% (> 6.81) for `ROI`. However, they aren't the highest ranking in terms of `ROI_rank` - three of the movies aren't even in the top 200. These three  had the three largest movie inflation adjusted budgets and also are the three latest movies released in the top 10. Perhaps this is suggesting that movies of late are requiring large budgets to achieve higher net profits at the expense of ROI?
#
# Notably many of the movies in the top 10  were all considered innovative films of their time. Star Wars, The Exorcist, Jaws and E.T were movies were so original and nothing released prior had come close to enthralling audiences with horror, suspense, special effects, etc. Avatar is also in the same vein with its innovative use of 3D technology and computer graphics.

# %% [markdown]
# ### Research Question 2 - How do the 10 highest ROI movies perform in terms of profitability?

# %%
df.nlargest(10, columns='ROI')
# Out:
#            id    imdb_id  popularity                original_title  \
# 7447    23827  tt1179904        1.12           Paranormal Activity
# 2449     2667  tt0185937        0.93       The Blair Witch Project
# 1354      985  tt0074486        0.33                    Eraserhead
# 7277      692  tt0069089        0.41                Pink Flamingos
# 7178     9372  tt0390521        0.26                 Super Size Me
# 242    299245  tt2309260        0.53                   The Gallows
# 7057       83  tt0374102        0.76                    Open Water
# 9762    30497  tt0072271        0.91  The Texas Chain Saw Massacre
# 7827     9659  tt0079501        2.01                       Mad Max
# 10759     948  tt0077651        1.20                     Halloween
#
#                                           genres release_date  vote_count  \
# 7447                              Horror|Mystery   2007-09-14         714
# 2449                              Horror|Mystery   1999-07-14         522
# ...

# %% [markdown]
# The above indicates that movies with extremely high `ROI` aren't necessarily the best performers for `net_profit` - they don't even feature in the top 300 for highest profitable movies. However, their net profit returns are very impressive considering the level of investment. The top two with stratospheric success, Paranormal Activity (mostly recorded with a series of cameras around a house) and The Blair Witch Project (fictional documentary film) were both very original films. The same could be said for Super Size Me (a documentary type film of a person eating McDonalds everyday for 30 days).
#
# Six of the top ten films are also original low budget horrors - Paranormal Activity, The Blair Witch Project, Eraserhead, The Gallows, The Texas Chain Saw Massacre and Halloween.
#
# There is a theme of 'originality' to both ROI and net profitability here.

# %% [markdown]
# ### Research Question 3 - When during the year are the most profitable movies released?

# %%
# Plot movies by month 
dims = (15, 15)
pyplot.subplots(figsize=dims)
ax = sns.swarmplot(x=df['release_month'], y=df['net_profit'], color=".1")
ax.set_title('Movie net profit by release month')
plt.show()

# %% [markdown]
# The swarmplot indicates that the most popular months (represented by the greater saturation of dots) for the release of profitable movies are May, June, July, November and December. These months also have a higher proportion of extremely profitable movies ($0.5b+ net profit).

# %%
# statistics by release_month
df.groupby('release_month').agg({'vote_average': [np.median, np.mean],
                                 'net_profit':[np.median, np.mean, np.sum, np.count_nonzero], 'ROI':[np.median,np.mean]})
# Out:
#               vote_average          net_profit                 \
#                     median mean         median           mean
# release_month
# 1                     6.10 6.02  70,320,412.92 123,742,834.25
# 2                     6.20 6.27  94,658,130.75 121,611,048.16
# 3                     6.30 6.29 109,569,752.07 201,030,727.94
# 4                     6.30 6.30  83,152,863.49 173,909,005.08
# 5                     6.40 6.45 182,294,701.12 265,182,138.10
# 6                     6.40 6.37 175,177,031.36 268,798,093.42
# 7                     6.40 6.36 127,097,522.21 218,775,780.76
# 8                     6.30 6.28  88,104,841.72 131,083,844.47
# 9                     6.60 6.57  95,509,150.00 131,388,425.63
# 10                    6.60 6.57 115,903,626.66 164,307,964.93
# 11                    6.60 6.52 144,582,540.85 244,664,805.88
# 12                    6.70 6.61 147,772,055.75 236,576,725.97
#
#                                                  ROI
# ...

# %% [markdown]
# The summary numbers above support the observations in the swarmplot. It is clear outliers are causing large discrepancies between the median and mean figures as well, so I will talk in terms of the median.
#
# The ROI median indicates that those movies with a high ROI (at least 3.7) are January, September and October. These are typically quieter months compared to the months with the release of profitable movies. It is hard to explain why this might be the case. Seasonal factors (winter), competition from other popular past time activities (sporting events) and lack of  holidays across the world (either national or school) during these months might conspire against production companies looking to profit on a big blockbuster movie or high quality film.  This would also mean less competition in these months and there would be less choices for moviegoers so this could increase the ROI for movies.

# %% [markdown]
# ### Research Question 4 - What is the correlation between the popularity score and net profit?

# %%
# Quick look at correlations between variables
df.corr(method='pearson')
# Out:
#                  id  popularity  vote_count  vote_average  release_year  \
# id             1.00        0.24        0.15          0.01          0.49
# popularity     0.24        1.00        0.75          0.32          0.24
# vote_count     0.15        0.75        1.00          0.39          0.31
# vote_average   0.01        0.32        0.39          1.00         -0.13
# release_year   0.49        0.24        0.31         -0.13          1.00
# budget_adj    -0.08        0.39        0.52         -0.00          0.21
# revenue_adj   -0.10        0.49        0.60          0.22         -0.06
# release_month  0.00        0.03       -0.00          0.17         -0.08
# net_profit    -0.09        0.46        0.56          0.24         -0.11
# ROI           -0.01       -0.01       -0.01         -0.01         -0.00
# np_rank        0.13       -0.40       -0.50         -0.19          0.09
# ROI_rank      -0.04       -0.00       -0.00         -0.23          0.27
#
# ...

# %% [markdown]
# The table above displays a 0.46 positive correlation between `popularity` and `net profit`. It is assumed that a higher popularity score represents great interest for a movie, and hopefully will translate to a high `net profit`. But what is the popularity score exactly?
#
# According to how the Popularity Score is [calculated](https://developers.themoviedb.org/3/getting-started/popularity) by TMDb, it seems it is based on a combination of a number of factors - votes for the day, views for the day, how many users have marked it as a "favourite" for the day, number of users who added it to their "watchlist". Immediately this raises concerns whether this score is actually legitimate - how could a movie before the internet age have this metric calculated fairly compared to movies released within the last 10 years?
#
# Further to this, the results seem to be based on traffic TMDb has logged through their information capturing mechanisms. It's not clear how this is managed. If it's just traffic through their website, what about viewers who do not use their website? And we don't know how reliable these scores are as there is no information available on the volumes of data points that make up the score.
#
# In any case, let's see how the average and median popularity score looks over time.

# %%
# Set dataframe filters for mean and median
popyear_mean = df.groupby('release_year')['popularity'].mean()
popyear_median = df.groupby('release_year')['popularity'].median()

# Figure size(width, height)
plt.figure(figsize=(12,6), dpi = 130)

# Label x-axis
plt.xlabel('Release Year of Movies', fontsize = 12)

# Label y-axis
plt.ylabel('Popularity Score of Movies', fontsize = 12)

plt.xlim(1960, 2015)

# Graph title
plt.title('How the popularity score of movies has changed over time')

# Plotting graphs
plt.plot(popyear_mean, label='mean popularity score')
plt.plot(popyear_median, label='median popularity score')

# Display the legend and show graph
plt.legend(loc='center')
plt.show()

# %% [markdown]
# The above graph illustrates that the mean and median popularity scores for movies is increasing over time. Of note are the increasingly higher scores since 2000 and the sudden jump from 2011 onwards. This seems to support my theory that the score favours movies released recently due to internet data being available in these years. Because of this potential bias it is probably not worthwhile relying on this metric too much.

# %% [markdown]
# ### Research Question 5 - What is the correlation between the financial variables and vote_average?
#
# Hopefully `vote_average` is more feasible than popularity. It is assumed this is rating out of 10, with 10 being highly favourible and 0 being least favourible on a spectrum.

# %%
# Set dataframe filters for mean and median
voteyear_mean = df.groupby('release_year')['vote_average'].mean()
voteyear_median = df.groupby('release_year')['vote_average'].median()

# Figure size(width, height)
plt.figure(figsize=(12,6), dpi = 130)

# Label x-axis
plt.xlabel('Release Year of Movies', fontsize = 10)

# Label y-axis
plt.ylabel('Average Rating Score of Movies', fontsize = 10)

plt.xlim(1960, 2015)

# Graph title
plt.title('How the average rating score of movies has changed over time')

# Plotting graphs
plt.plot(voteyear_mean, label='mean average rating score')
plt.plot(voteyear_median, label='median average rating score')

# Display the legend and show graph
plt.legend(loc='center')
plt.show()

# %%
# let's see this with a trendline
ax = sns.lmplot(x='release_year', y='vote_average', data=df, size=8)
plt.title('Trend between release_year and vote_average')
plt.show()

# %%
# get the correlation coefficient between vote_average and release_year.
df['vote_average'].corr(df['release_year'])
# Out:
# -0.13003406717447344

# %% [markdown]
# The above graphs visually represent a negligible downward trend with the average rating score of movies through the passage of time. This is also reflected by -0.13 correlation score.

# %%
# check the number of votes
df['vote_count'].describe()
# Out:
# count   1,757.00
# mean      887.93
# std     1,139.69
# min        10.00
# 25%       184.00
# 50%       480.00
# 75%     1,097.00
# max     9,767.00
# Name: vote_count, dtype: float64

# %% [markdown]
# The number of votes seems to be reasonable in the scheme of things - more than 25% of movies had at least 184 votes to generate the average rating scores (though more would give me more confidence). So on this basis, I think it is reasonable to use this for our analysis on whether there is correlation with the financial variables (`budget_adj`, `revenue_adj`, `net_profit` and `ROI`). While we have dismissed the use of the `popularity` score, I have noticed that a high `popularity` score has a moderate positive correlation of 0.32 with `vote_average`. The assumption being a movie will obtain a higher rating if its popularity is high. So this helps negate the fact that some movies don't have as many votes to form a meaningful `vote_average`.

# %%
# correlations with heat map
plt.subplots(figsize=(20,15))
plt.title('Heatmap correlations between dataset variables')
sns.heatmap(df.corr(), annot=True, fmt=".2f")

# %% [markdown]
# There are weak correlation scores between the `vote_average` and the `revenue_adj` (0.22) and `net_profit` (0.24). This could suggest that collecting average rating scores from movie test screenings might not be as beneficial for predicting commercial success as people believe because the correlation is weak.
#
# There is virtually no correlation between budget_adj and ROI.
#
# There is a moderate correlation (0.59) between `revenue_adj` and `budget_adj`. The assumption that to make lots of money you need spend lots of money may hold here.
#
# It is difficult to say what these correlations could mean without further testing and analysis. There are many factors that can influence the level of commercial success a movie could have that we have not covered - the cast, the director, the production company, the genres, etc.

# %% [markdown]
# <a id='conclusions'></a>
# ## Conclusions

# %% [markdown]
# The dataset was filtered to focus on the top 50% movies that were the most profitable or had the highest ROI. From this subset, it was found that:
# 1. Movies that were in the top 10 for net profit possessed high ROIs. However, they did not rank in the top 10 (in fact, failed to make the top 30) when compared against movies with the highest ROI.
# 2. Originality and the ability to 'wow' audiences with an experience they have not seen or felt seems to be a common theme for highly profitable movies in the top 10 for net profit and ROI no matter their budget.
# 3. May, June, July, November and December are popular months to release highly profitable movies.
# 4. Movies with a high ROI (at least 3.7 times) seem to be released in the quieter months of January, September and October.
# 5. There is a moderate correlation between `revenue_adj` and `budget_adj`, suggesting you need to spend more money to make more money.
# 6. There is a weak correlation between the `vote_avg` and the two financial variables `revenue_adj` and `net_profit`. This may suggest not placing too much emphasis on movie commerical success from advanced movie screenings with audiences.

# %% [markdown]
# Limitations:
# 1. Could not say with absolute confidence the data is correct in the dataset. The financial data seems to have quite a few inconsistencies as identified and discussed above. It is possible that a lot of movies that generated profits have been excluded. Conversely, it is possible that movies that feature in the dataset do not have their financial figures captured correctly.
# 2. At least 5,696 movies did not have revenue or budget information and had to be removed. This is more than half the original data set, so making conclusions on a much smaller subset of the original may not be reliable.
# 2. Not enough information was available on popularity score to determine how it was derived. It could have been a useful measure to find correlations against other variables.
# 3. Generally only the numerical values were used. Cast, directors, etc were not considered to determine their part in a movie's commercial success.
